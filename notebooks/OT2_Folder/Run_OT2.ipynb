# %%
from OT2_code import Run_OT2

# %%
exp = Run_OT2.run_protocol()

# %% [markdown]
# Run this line of code to create the OT2 protocol. You will choose where to place the stock solutions, the wellplate and the pipette tipracks on the OT2 robot deck.
#
# <img src= "images/OT2_Deck.png"  width = "300" />

# %%
exp.create_protocol()
# Out:
# Enter position of the falcon 48 wellplate (1-11): 8
# Enter position of the stock solution (1-11): 2
# Enter position of the 1000uL tiprack (1-11): 5
# Enter position of the 300uL tiprack (1-11): 3

# %% [markdown]
# Run this code to determine how many stock solutions you need and where to place them. 'Ranges' tells us the samples that the stock solution will be used on. 'Stock Wells' tells us where to place the stock solutions on the OT2 deck.

# %%
exp.stock_position()
# Out:
# /home/huat/.opentrons/robot_settings.json not found. Loading defaults
# /home/huat/.opentrons/deck_calibration.json not found. Loading defaults
# CTAB-stock	 {'Ranges': [[0, 40], [40, 48]], 'Stock Wells': [A1 of Opentrons 96 Tip Rack 1000 µL on 2, A2 of Opentrons 96 Tip Rack 1000 µL on 2]}
# Water-stock	 {'Ranges': [[0, 47], [47, 48]], 'Stock Wells': [A3 of Opentrons 96 Tip Rack 1000 µL on 2, A4 of Opentrons 96 Tip Rack 1000 µL on 2]}
# Chloroauric-stock	 {'Ranges': [[0, 48]], 'Stock Wells': [A5 of Opentrons 96 Tip Rack 1000 µL on 2]}
# Ascorbic_Acid-stock	 {'Ranges': [[0, 48]], 'Stock Wells': [A6 of Opentrons 96 Tip Rack 1000 µL on 2]}
# Silver_Nitrate-stock	 {'Ranges': [[0, 48]], 'Stock Wells': [A7 of Opentrons 96 Tip Rack 1000 µL on 2]}
# Gold_Seeds-stock	 {'Ranges': [[0, 48]], 'Stock Wells': [A8 of Opentrons 96 Tip Rack 1000 µL on 2]}

# %% [markdown]
# Run this line of code to simulate the OT2 protocol. Briefly read through the actions to make sure they make sense.

# %%
exp.simulate_protocol()
# Out:
# Picking up tip from A1 of Opentrons 96 Tip Rack 1000 µL on 5
# Aspirating 416.0 uL from A1 of Opentrons 96 Tip Rack 1000 µL on 2 at 500.0 uL/sec
# Dispensing 416.0 uL into A1 of Opentrons 96 Tip Rack 1000 µL on 8 at 700.0 uL/sec
# Aspirating 416.0 uL from A1 of Opentrons 96 Tip Rack 1000 µL on 2 at 500.0 uL/sec
# Dispensing 416.0 uL into A2 of Opentrons 96 Tip Rack 1000 µL on 8 at 700.0 uL/sec
# Aspirating 416.0 uL from A1 of Opentrons 96 Tip Rack 1000 µL on 2 at 500.0 uL/sec
# Dispensing 416.0 uL into A3 of Opentrons 96 Tip Rack 1000 µL on 8 at 700.0 uL/sec
# Aspirating 416.0 uL from A1 of Opentrons 96 Tip Rack 1000 µL on 2 at 500.0 uL/sec
# Dispensing 416.0 uL into A4 of Opentrons 96 Tip Rack 1000 µL on 8 at 700.0 uL/sec
# Aspirating 416.0 uL from A1 of Opentrons 96 Tip Rack 1000 µL on 2 at 500.0 uL/sec
# Dispensing 416.0 uL into A5 of Opentrons 96 Tip Rack 1000 µL on 8 at 700.0 uL/sec
# Aspirating 416.0 uL from A1 of Opentrons 96 Tip Rack 1000 µL on 2 at 500.0 uL/sec
# ...

# %% [markdown]
# When you are ready to perform the experiment, run this code. The OT2 robot should start running.

# %%
exp.execute_protocol()
